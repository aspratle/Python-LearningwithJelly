# %% [markdown]
# <h1><center>Python - Pandas</center></h1>
#
# <center><img src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSqUfFmqMthdkODwkTILaPSl97HNaYRuKa8uA&usqp=CAU"></center>

# %% [markdown]
# ## Objectives
#
# - Pandas Library (why should you care)
# - What is the Pandas Library used for?
# - Reading in Data as a DataFrame
# - DataFrame Exploration - Methods & Attributes

# %% [markdown]
# ## Pandas in Data Science...
#
# - Used for data cleaning and preparation (about 60-80% of most DS jobs)
# - Has a DataFrame object type (this makes modeling and analysis easier than just stand alone arrays)
# - Exploratory Data Analysis (need to explore your data FIRST)
#
# <center><img src="https://files.realpython.com/media/A-Guide-to-Pandas-Dataframes_Watermarked.7330c8fd51bb.jpg"></center>

# %% [markdown]
# ## What is Pandas?
#
# - A power data analytics tool (library) built on top of **NUMPY**
#
# - Library used for data wrangling,data cleaning, and more!
#
# - Can be used to read in datafiles
#
# - Popular!

# %% [markdown]
# ## Reading in data as a DataFrame

# %%
import numpy as np 
import pandas as pd #need the library!

df = pd.read_csv('data/king_county.csv') #reads in a csv file

# %% [markdown]
# ## Explore the Data - Methods & Attributes

# %%
# What's in the first 5 rows of my Dataframe? (method) 

df.head()
# Out:
#            id     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0  7129300520  221900.0         3       1.00         1180      5650     1.0
# 1  6414100192  538000.0         3       2.25         2570      7242     2.0
# 2  5631500400  180000.0         2       1.00          770     10000     1.0
# 3  2487200875  604000.0         4       3.00         1960      5000     1.0
# 4  1954400510  510000.0         3       2.00         1680      8080     1.0
#
#    waterfront  view  condition  grade  sqft_above  sqft_basement
# 0           0     0          3      7        1180              0
# 1           0     0          3      7        2170            400
# 2           0     0          3      6         770              0
# 3           0     0          5      7        1050            910
# 4           0     0          3      8        1680              0

# %%
# What's in the last 5 rows of my DataFrame? (method)

df.tail()
# Out:
#                id     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 21608   263000018  360000.0         3       2.50         1530      1131
# 21609  6600060120  400000.0         4       2.50         2310      5813
# 21610  1523300141  402101.0         2       0.75         1020      1350
# 21611   291310100  400000.0         3       2.50         1600      2388
# 21612  1523300157  325000.0         2       0.75         1020      1076
#
#        floors  waterfront  view  condition  grade  sqft_above  sqft_basement
# 21608     3.0           0     0          3      8        1530              0
# 21609     2.0           0     0          3      8        2310              0
# 21610     2.0           0     0          3      7        1020              0
# 21611     2.0           0     0          3      8        1600              0
# 21612     2.0           0     0          3      7        1020              0

# %%
#What are my columns and the datatypes stored in those columns? (method)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   price          21613 non-null  float64
#  2   bedrooms       21613 non-null  int64
#  3   bathrooms      21613 non-null  float64
#  4   sqft_living    21613 non-null  int64
#  5   sqft_lot       21613 non-null  int64
#  6   floors         21613 non-null  float64
#  7   waterfront     21613 non-null  int64
#  8   view           21613 non-null  int64
#  9   condition      21613 non-null  int64
#  10  grade          21613 non-null  int64
#  11  sqft_above     21613 non-null  int64
#  12  sqft_basement  21613 non-null  int64
# dtypes: float64(3), int64(10)
# memory usage: 2.1 MB

# %%
#Summary stats of my columns (method)

df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
#How many rows and columns in my dataframe? (attribute)

df.shape
# Out:
# (21613, 13)

# %%
#What are my column names? (attribute)

df.columns #may be better to do a .info()
# Out:
# Index(['id', 'price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
#        'floors', 'waterfront', 'view', 'condition', 'grade', 'sqft_above',
#        'sqft_basement'],
#       dtype='object')

# %% [markdown]
# ## Locate and filter for certain rows

# %%
#loc is for label location filter based on a column label (name)

df.loc[df.bedrooms>=4]
# Out:
#                id      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 3      2487200875   604000.0         4       3.00         1960      5000
# 5      7237550310  1225000.0         4       4.50         5420    101930
# 14     1175000570   530000.0         5       2.00         1810      4850
# 15     9297300055   650000.0         4       3.00         2950      5000
# 17     6865200140   485000.0         4       1.00         1600      4300
# ...           ...        ...       ...        ...          ...       ...
# 21599  7202300110   810000.0         4       3.00         3990      7838
# 21600   249000205  1537000.0         5       3.75         4470      8088
# 21605  3448900210   610685.0         4       2.50         2520      6023
# 21606  7936000429  1007500.0         4       3.50         3510      7200
# 21609  6600060120   400000.0         4       2.50         2310      5813
#
#        floors  waterfront  view  condition  grade  sqft_above  sqft_basement
# ...

# %%
#select certain rows I want to look at 

df.iloc[0:15]
# Out:
#             id      price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0   7129300520   221900.0         3       1.00         1180      5650     1.0
# 1   6414100192   538000.0         3       2.25         2570      7242     2.0
# 2   5631500400   180000.0         2       1.00          770     10000     1.0
# 3   2487200875   604000.0         4       3.00         1960      5000     1.0
# 4   1954400510   510000.0         3       2.00         1680      8080     1.0
# 5   7237550310  1225000.0         4       4.50         5420    101930     1.0
# 6   1321400060   257500.0         3       2.25         1715      6819     2.0
# 7   2008000270   291850.0         3       1.50         1060      9711     1.0
# 8   2414600126   229500.0         3       1.00         1780      7470     1.0
# 9   3793500160   323000.0         3       2.50         1890      6560     2.0
# 10  1736800520   662500.0         3       2.50         3560      9796     1.0
# ...

# %% [markdown]
# ## I can also get correlations (this is powerful)

# %%
df.corr()
# Out:
#                      id     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id             1.000000 -0.016762  0.001286   0.005160    -0.012258 -0.132109
# price         -0.016762  1.000000  0.308350   0.525138     0.702035  0.089661
# bedrooms       0.001286  0.308350  1.000000   0.515884     0.576671  0.031703
# bathrooms      0.005160  0.525138  0.515884   1.000000     0.754665  0.087740
# sqft_living   -0.012258  0.702035  0.576671   0.754665     1.000000  0.172826
# sqft_lot      -0.132109  0.089661  0.031703   0.087740     0.172826  1.000000
# floors         0.018525  0.256794  0.175429   0.500653     0.353949 -0.005201
# waterfront    -0.002721  0.266369 -0.006582   0.063744     0.103818  0.021604
# view           0.011592  0.397293  0.079532   0.187737     0.284611  0.074710
# condition     -0.023783  0.036362  0.028472  -0.124982    -0.058753 -0.008958
# grade          0.008130  0.667434  0.356967   0.664983     0.762704  0.113621
# ...

# %% [markdown]
# <h1><center>The End</center></h1>

# %%
from traitlets.config.manager import BaseJSONConfigManager
from pathlib import Path
path = Path.home() / ".jupyter" / "nbconfig"
cm = BaseJSONConfigManager(config_dir=str(path))
cm.update(
    "rise",
    {
        "theme": "solarized",
        "transition": "fade",
        "start_slideshow_at": "selected",
        "footer": "  <h3>Learning with Jelly</h3>",
        "header": "  <h2>Python - Pandas</h2>",
        "enable_chalkboard": True
     }
)
# Out:
# {'theme': 'solarized',
#  'transition': 'fade',
#  'start_slideshow_at': 'selected',
#  'autolaunch': False,
#  'width': '100%',
#  'height': '100%',
#  'header': '  <h2>Python - Pandas</h2>',
#  'footer': '  <h3>Learning with Jelly</h3>',
#  'scroll': True,
#  'enable_chalkboard': True,
#  'slideNumber': True,
#  'center': False,
#  'controlsLayout': 'edges',
#  'hash': True}
