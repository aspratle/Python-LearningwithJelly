# %% [markdown]
# <h1><center>Python - Seaborn</center></h1>
#
# <center><img src="https://seaborn.pydata.org/_static/logo-wide-lightbg.svg"></center>

# %% [markdown]
# ## Objectives
#
# - Seaborn (why should you care)
# - What is Seaborn used for?
# - Scatterplot
# - Facetted Histograms (displot)
# - Boxplot
# - Heatmap

# %% [markdown]
# ## Seaborn in Data Science...
#
# - Fancier than MatplotLib (more client facing) -- built on top of Matplotlib
# - Storytelling is important in data analytics/data science
# - Get to know what's in your data before modeling (it's part of the process)
#
# <center><img src="https://miro.medium.com/max/1400/1*3VgCwcZraA0u5hMHpRhJcw.png"></center>

# %% [markdown]
# ## What is Seaborn
#
# - Library for creating higher level "fancier" visuals than matplotlib
# - Preferred over matplotlib when you need graphs for presentations, reports, etc.
#     - Better for client facing materials!

# %% [markdown]
# ## Scatterplot

# %%
#Let's do a scatterplot of our data

import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns #we need the library!

df = pd.read_csv('data/king_county.csv') 
df.head()
# Out:
#            id     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0  7129300520  221900.0         3       1.00         1180      5650     1.0
# 1  6414100192  538000.0         3       2.25         2570      7242     2.0
# 2  5631500400  180000.0         2       1.00          770     10000     1.0
# 3  2487200875  604000.0         4       3.00         1960      5000     1.0
# 4  1954400510  510000.0         3       2.00         1680      8080     1.0
#
#    waterfront  view  condition  grade  sqft_above  sqft_basement
# 0           0     0          3      7        1180              0
# 1           0     0          3      7        2170            400
# 2           0     0          3      6         770              0
# 3           0     0          5      7        1050            910
# 4           0     0          3      8        1680              0

# %%
#simple scatterplot on square feet living and price 

fig, ax = plt.subplots(figsize=(10,10))

X = df['sqft_living']
y = df['price']

sns.scatterplot(x=X, y=y)
# Out:
# <AxesSubplot:xlabel='sqft_living', ylabel='price'>

# %%
# can add another column to change the color of the points 
sns.scatterplot(x=X, y=y, hue=df['waterfront'])
# Out:
# <AxesSubplot:xlabel='sqft_living', ylabel='price'>

# %%
#change the colors and add labels 

sns.scatterplot(x=X, y=y, hue=df['waterfront'], palette="Set2")
plt.title ("Square Feet Living vs. Price based on Waterfront")
plt.xlabel("Square Feet Living")
plt.ylabel("Price")
plt.show()

# %% [markdown]
# ## Facetted Histograms (Displot)

# %%
df["condition"].value_counts()
# Out:
# 3    14031
# 4     5679
# 5     1701
# 2      172
# 1       30
# Name: condition, dtype: int64

# %%
#multiple histograms at once -- may take a second to run

sns.set_theme(style="darkgrid")

sns.displot(x=df["sqft_living"], col=df["condition"],
           binwidth=3, facet_kws=dict(margin_titles=True),)

# %% [markdown]
# ## Boxplot

# %%
sns.set_theme(style="ticks", palette="pastel")

sns.boxplot(x=df["waterfront"], y=df["sqft_living"])
# Out:
# <AxesSubplot:xlabel='waterfront', ylabel='sqft_living'>

# %% [markdown]
# ## Heatmap

# %%
## good for looking at relationships among predictors and predictors vs. target (important in modeling!)

corrs = df.corr()

cmap = sns.diverging_palette(230, 20, as_cmap=True)

sns.heatmap(corrs, cmap=cmap, vmax=1, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
# Out:
# <AxesSubplot:>

# %% [markdown]
# <h1><center>The End</center></h1>

# %%
from traitlets.config.manager import BaseJSONConfigManager
from pathlib import Path
path = Path.home() / ".jupyter" / "nbconfig"
cm = BaseJSONConfigManager(config_dir=str(path))
cm.update(
    "rise",
    {
        "theme": "white",
        "transition": "fade",
        "start_slideshow_at": "selected",
        "footer": "  <h3>Learning with Jelly</h3>",
        "header": "  <h2>Python - Seaborn</h2>",
        "enable_chalkboard": True
     }
)
